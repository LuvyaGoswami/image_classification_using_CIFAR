# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train,y_train),(X_test,y_test)=datasets.cifar10.load_data()

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
y_train = y_train.reshape(-1,)
y_train[:5]
# Out:
# array([6, 9, 9, 4, 1], dtype=uint8)

# %%
y_test = y_test.reshape(-1,)

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
def plot_sample(X,y,index):
    plt.figure(figsize=(16,16))
    plt.imshow(X[index])

# %%
#NORMALIZING THE TRAINING DATA
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# BUILDING AN ARTIFICAL NEURAL NETWORK FOR IMAGE CLASSIFICATION
ann = models.Sequential([
        layers.Flatten(input_shape=(32,32,3)),
        layers.Dense(3000, activation='relu'),
        layers.Dense(1000, activation='relu'),
        layers.Dense(10, activation='softmax')    
    ])

ann.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

ann.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 92s 57ms/step - loss: 1.8070 - accuracy: 0.3561
# Epoch 2/5
# 1563/1563 [==============================] - 86s 55ms/step - loss: 1.6193 - accuracy: 0.4296
# Epoch 3/5
# 1563/1563 [==============================] - 93s 59ms/step - loss: 1.5366 - accuracy: 0.4590
# Epoch 4/5
# 1563/1563 [==============================] - 90s 57ms/step - loss: 1.4774 - accuracy: 0.4802
# Epoch 5/5
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.4284 - accuracy: 0.4974

# %%
from sklearn.metrics import confusion_matrix , classification_report
y_pred = ann.predict(X_test)
y_pred_classes = [np.argmax(element) for element in y_pred]

print("Classification Report: \n", classification_report(y_test, y_pred_classes))
# Out:
# 313/313 [==============================] - 6s 18ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.48      0.55      1000
#            1       0.65      0.48      0.56      1000
#            2       0.46      0.24      0.31      1000
#            3       0.30      0.45      0.36      1000
#            4       0.51      0.27      0.35      1000
#            5       0.42      0.32      0.36      1000
#            6       0.61      0.42      0.49      1000
#            7       0.38      0.70      0.49      1000
#            8       0.78      0.38      0.51      1000
#            9       0.36      0.79      0.49      1000
#
#     accuracy                           0.45     10000
#    macro avg       0.51      0.45      0.45     10000
# weighted avg       0.51      0.45      0.45     10000

# %%
#BUILDING AN CONVOLUTIONAL NEURAL NETWORK TO TRAIN OUR IMAGES
cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
cnn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
cnn.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 34s 21ms/step - loss: 1.5104 - accuracy: 0.4548
# Epoch 2/10
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.1535 - accuracy: 0.5921
# Epoch 3/10
# 1563/1563 [==============================] - 26s 16ms/step - loss: 1.0143 - accuracy: 0.6458
# Epoch 4/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.9348 - accuracy: 0.6747
# Epoch 5/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8738 - accuracy: 0.6954
# Epoch 6/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8171 - accuracy: 0.7155
# Epoch 7/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.7738 - accuracy: 0.7301
# Epoch 8/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.7383 - accuracy: 0.7427
# Epoch 9/10
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.7024 - accuracy: 0.7534
# Epoch 10/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.6692 - accuracy: 0.7649

# %%
cnn.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.9086 - accuracy: 0.6926
# [0.9085515737533569, 0.6926000118255615]

# %%
y_pred = cnn.predict(X_test)
y_pred[:5]
# Out:
# 313/313 [==============================] - 3s 9ms/step
# array([[2.26703612e-03, 3.92692443e-03, 1.15264170e-02, 8.32941294e-01,
#         9.02897562e-04, 1.01521194e-01, 1.57036688e-02, 7.14819762e-04,
#         2.35268995e-02, 6.96887961e-03],
#        [1.22086858e-04, 2.42535807e-02, 5.10530063e-09, 2.32054234e-08,
#         1.14650989e-09, 5.08594722e-10, 1.59927271e-09, 3.98072214e-10,
#         9.75593626e-01, 3.06471047e-05],
#        [6.30861223e-02, 7.72901475e-01, 1.99634093e-03, 2.82531767e-03,
#         3.94824194e-03, 1.37369178e-04, 3.86464351e-04, 4.20974713e-04,
#         1.46951899e-01, 7.34579237e-03],
#        [6.74691439e-01, 2.50746775e-02, 1.40901813e-02, 6.37861528e-03,
#         4.54714522e-03, 3.90938621e-05, 3.77011107e-04, 4.65752382e-04,
#         2.73589820e-01, 7.46220467e-04],
#        [1.15086209e-06, 3.44624254e-06, 1.83999445e-02, 1.30807802e-01,
#         2.19946817e-01, 2.05435529e-02, 6.10056579e-01, 1.81380441e-04,
#         4.83736258e-05, 1.09212215e-05]], dtype=float32)

# %%
y_classes = [np.argmax(element) for element in y_pred]
y_classes[:5]
# Out:
# [3, 8, 1, 0, 6]

# %%
y_test[:5]
# Out:
# array([3, 8, 8, 0, 6], dtype=uint8)

# %%
plot_sample(X_test, y_test,3)

# %%
classes[y_classes[3]]
# Out:
# 'airplane'
